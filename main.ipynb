# %%
import requests
from bs4 import BeautifulSoup

# %%
def extract_information(div_element):
    country_info = {}

    # Extract country name
    try:
        country_name = div_element.find('a').text
        country_info['country_name'] = country_name
    except AttributeError:
        country_info['country_name'] = None

    # Extract total distance
    try:
        note_element = div_element.find('strong', text='note:').find_next_sibling(text=True).strip()
        country_info['note'] = note_element
    except AttributeError:
        country_info['note'] = None

    # Extract Note element
    try:
        total_distance = div_element.find('strong', text='total:').find_next_sibling(text=True).strip()
        country_info['total_distance'] = total_distance
    except AttributeError:
        country_info['total_distance'] = None

    # Extract bordering countries and their distances
    try:
        border_info = div_element.find('strong', text='border countries (6):').find_next_sibling(text=True).strip()
        border_info = border_info.split(';')
        border_countries = {}
        for border in border_info:
            border_parts = border.strip().split(' ')
            border_country = border_parts[0]
            border_distance = ' '.join(border_parts[1:]).strip()
            border_countries[border_country] = border_distance
        country_info['border_countries'] = border_countries
    except AttributeError:
        country_info['border_countries'] = None

    return country_info

# %%
## get the page:
def get_page(url):
    response = requests.get(url)
    if response.status_code == 200:
        return BeautifulSoup(response.content, 'html.parser')

# %%
def scrape_webpage(soup):
    contry_data=[]
    selected_elements = soup.select('#index-content-section > div > div.col-lg-9.col-md-12.col-sm-12 div')
    for element in selected_elements:
        contry_data.append(extract_information(element))
    return contry_data

# %%
url = "https://www.cia.gov/the-world-factbook/field/land-boundaries/"
soup=get_page(url)

# %%
elements=scrape_webpage(soup)
elements
# Out:
# /tmp/ipykernel_28009/651187709.py:13: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   note_element = div_element.find('strong', text='note:').find_next_sibling(text=True).strip()
# /tmp/ipykernel_28009/651187709.py:20: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   total_distance = div_element.find('strong', text='total:').find_next_sibling(text=True).strip()
# /tmp/ipykernel_28009/651187709.py:27: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   border_info = div_element.find('strong', text='border countries (6):').find_next_sibling(text=True).strip()
# [{'country_name': 'Afghanistan',
#   'note': None,
#   'total_distance': '5,987 km',
#   'border_countries': {'China': '91 km',
#    'Iran': '921 km',
#    'Pakistan': '2,670 km',
#    'Tajikistan': '1,357 km',
#    'Turkmenistan': '804 km',
#    'Uzbekistan': '144 km'}},
#  {'country_name': 'Akrotiri',
#   'note': None,
#   'total_distance': '48 km',
#   'border_countries': None},
#  {'country_name': 'Albania',
#   'note': None,
#   'total_distance': '691 km',
#   'border_countries': None},
#  {'country_name': 'Algeria',
#   'note': None,
#   'total_distance': '6,734 km',
#   'border_countries': {'Libya': '989 km',
#    'Mali': '1,359 km',
#    'Mauritania': '460 km',
#    'Morocco': '1,941 km',
#    'Niger': '951 km',
#    'Tunisia': '1,034 km'}},
#  {'country_name': 'American Samoa',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Andorra',
#   'note': None,
#   'total_distance': '118 km',
#   'border_countries': None},
#  {'country_name': 'Angola',
#   'note': None,
#   'total_distance': '5,369 km',
#   'border_countries': None},
#  {'country_name': 'Anguilla',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Antarctica',
#   'note': 'see entry on Disputes - international',
#   'total_distance': None,
#   'border_countries': None},
#  {'country_name': 'Antigua and Barbuda',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Argentina',
#   'note': None,
#   'total_distance': '11,968 km',
#   'border_countries': None},
#  {'country_name': 'Armenia',
#   'note': None,
#   'total_distance': '1,570 km',
#   'border_countries': None},
#  {'country_name': 'Aruba',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Ashmore and Cartier Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Australia',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Austria',
#   'note': None,
#   'total_distance': '2,524 km',
#   'border_countries': None},
#  {'country_name': 'Azerbaijan',
#   'note': None,
#   'total_distance': '2,468 km',
#   'border_countries': None},
#  {'country_name': 'Bahamas, The',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Bahrain',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Bangladesh',
#   'note': None,
#   'total_distance': '4,413 km',
#   'border_countries': None},
#  {'country_name': 'Barbados',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Belarus',
#   'note': None,
#   'total_distance': '3,599 km',
#   'border_countries': None},
#  {'country_name': 'Belgium',
#   'note': None,
#   'total_distance': '1,297 km',
#   'border_countries': None},
#  {'country_name': 'Belize',
#   'note': None,
#   'total_distance': '542 km',
#   'border_countries': None},
#  {'country_name': 'Benin',
#   'note': None,
#   'total_distance': '2,123 km',
#   'border_countries': None},
#  {'country_name': 'Bermuda',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Bhutan',
#   'note': None,
#   'total_distance': '1,136 km',
#   'border_countries': None},
#  {'country_name': 'Bolivia',
#   'note': None,
#   'total_distance': '7,252 km',
#   'border_countries': None},
#  {'country_name': 'Bosnia and Herzegovina',
#   'note': None,
#   'total_distance': '1,543 km',
#   'border_countries': None},
#  {'country_name': 'Botswana',
#   'note': None,
#   'total_distance': '4,347.15 km',
#   'border_countries': None},
#  {'country_name': 'Bouvet Island',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Brazil',
#   'note': None,
#   'total_distance': '16,145 km',
#   'border_countries': None},
#  {'country_name': 'British Indian Ocean Territory',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'British Virgin Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Brunei',
#   'note': None,
#   'total_distance': '266 km',
#   'border_countries': None},
#  {'country_name': 'Bulgaria',
#   'note': None,
#   'total_distance': '1,806 km',
#   'border_countries': None},
#  {'country_name': 'Burkina Faso',
#   'note': None,
#   'total_distance': '3,611 km',
#   'border_countries': {'Benin': '386 km',
#    'Cote': "d'Ivoire 545 km",
#    'Ghana': '602 km',
#    'Mali': '1325 km',
#    'Niger': '622 km',
#    'Togo': '131 km'}},
#  {'country_name': 'Burma',
#   'note': None,
#   'total_distance': '6,522 km',
#   'border_countries': None},
#  {'country_name': 'Burundi',
#   'note': None,
#   'total_distance': '1,140 km',
#   'border_countries': None},
#  {'country_name': 'Cabo Verde',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Cambodia',
#   'note': None,
#   'total_distance': '2,530 km',
#   'border_countries': None},
#  {'country_name': 'Cameroon',
#   'note': None,
#   'total_distance': '5,018 km',
#   'border_countries': {'Central': 'African Republic 901 km',
#    'Chad': '1,116 km',
#    'Republic': 'of the Congo 494 km',
#    'Equatorial': 'Guinea 183 km',
#    'Gabon': '349 km',
#    'Nigeria': '1975 km'}},
#  {'country_name': 'Canada',
#   'note': None,
#   'total_distance': '8,892 km',
#   'border_countries': None},
#  {'country_name': 'Cayman Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Central African Republic',
#   'note': None,
#   'total_distance': '5,920 km',
#   'border_countries': None},
#  {'country_name': 'Chad',
#   'note': None,
#   'total_distance': '6,406 km',
#   'border_countries': {'Cameroon': '1,116 km',
#    'Central': 'African Republic 1,556 km',
#    'Libya': '1,050 km',
#    'Niger': '1,196 km',
#    'Nigeria': '85 km',
#    'Sudan': '1,403 km'}},
#  {'country_name': 'Chile',
#   'note': None,
#   'total_distance': '7,801 km',
#   'border_countries': None},
#  {'country_name': 'China',
#   'note': None,
#   'total_distance': '22,457 km',
#   'border_countries': None},
#  {'country_name': 'Christmas Island',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Clipperton Island',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Cocos (Keeling) Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Colombia',
#   'note': None,
#   'total_distance': '6,672 km',
#   'border_countries': None},
#  {'country_name': 'Comoros',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Congo, Democratic Republic of the',
#   'note': None,
#   'total_distance': '11,027 km',
#   'border_countries': None},
#  {'country_name': 'Congo, Republic of the',
#   'note': None,
#   'total_distance': '5,554 km',
#   'border_countries': None},
#  {'country_name': 'Cook Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Coral Sea Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Costa Rica',
#   'note': None,
#   'total_distance': '661 km',
#   'border_countries': None},
#  {'country_name': "Cote d'Ivoire",
#   'note': None,
#   'total_distance': '3,458 km',
#   'border_countries': None},
#  {'country_name': 'Croatia',
#   'note': None,
#   'total_distance': '2,237 km',
#   'border_countries': None},
#  {'country_name': 'Cuba',
#   'note': 'Guantanamo Naval Base is leased by the US and remains part of Cuba',
#   'total_distance': '28.5 km',
#   'border_countries': None},
#  {'country_name': 'Curacao',
#   'note': None,
#   'total_distance': None,
#   'border_countries': None},
#  {'country_name': 'Cyprus',
#   'note': None,
#   'total_distance': '156 km',
#   'border_countries': None},
#  {'country_name': 'Czechia',
#   'note': None,
#   'total_distance': '2,046 km',
#   'border_countries': None},
#  {'country_name': 'Denmark',
#   'note': None,
#   'total_distance': '141 km',
#   'border_countries': None},
#  {'country_name': 'Dhekelia',
#   'note': None,
#   'total_distance': '108 km',
#   'border_countries': None},
#  {'country_name': 'Djibouti',
#   'note': None,
#   'total_distance': '528 km',
#   'border_countries': None},
#  {'country_name': 'Dominica',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Dominican Republic',
#   'note': None,
#   'total_distance': '376 km',
#   'border_countries': None},
#  {'country_name': 'Ecuador',
#   'note': None,
#   'total_distance': '2,237 km',
#   'border_countries': None},
#  {'country_name': 'Egypt',
#   'note': None,
#   'total_distance': '2,612 km',
#   'border_countries': None},
#  {'country_name': 'El Salvador',
#   'note': None,
#   'total_distance': '590 km',
#   'border_countries': None},
#  {'country_name': 'Equatorial Guinea',
#   'note': None,
#   'total_distance': '528 km',
#   'border_countries': None},
#  {'country_name': 'Eritrea',
#   'note': None,
#   'total_distance': '1,840 km',
#   'border_countries': None},
#  {'country_name': 'Estonia',
#   'note': None,
#   'total_distance': '657 km',
#   'border_countries': None},
#  {'country_name': 'Eswatini',
#   'note': None,
#   'total_distance': '546 km',
#   'border_countries': None},
#  {'country_name': 'Ethiopia',
#   'note': None,
#   'total_distance': '5,925 km',
#   'border_countries': {'Djibouti': '342 km',
#    'Eritrea': '1,033 km',
#    'Kenya': '867 km',
#    'Somalia': '1,640 km',
#    'South': 'Sudan 1,299 km',
#    'Sudan': '744 km'}},
#  {'country_name': 'European Union',
#   'note': 'data for European continent only',
#   'total_distance': '13,770 km',
#   'border_countries': None},
#  {'country_name': 'Falkland Islands (Islas Malvinas)',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Faroe Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Fiji',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Finland',
#   'note': None,
#   'total_distance': '2,563 km',
#   'border_countries': None},
#  {'country_name': 'France',
#   'note': None,
#   'total_distance': '3,956 km',
#   'border_countries': None},
#  {'country_name': 'French Polynesia',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'French Southern and Antarctic Lands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Gabon',
#   'note': None,
#   'total_distance': '3,261 km',
#   'border_countries': None},
#  {'country_name': 'Gambia, The',
#   'note': None,
#   'total_distance': '749 km',
#   'border_countries': None},
#  {'country_name': 'Gaza Strip',
#   'note': None,
#   'total_distance': '72 km',
#   'border_countries': None},
#  {'country_name': 'Georgia',
#   'note': None,
#   'total_distance': '1,814 km',
#   'border_countries': None},
#  {'country_name': 'Germany',
#   'note': None,
#   'total_distance': '3,694 km',
#   'border_countries': None},
#  {'country_name': 'Ghana',
#   'note': None,
#   'total_distance': '2,420 km',
#   'border_countries': None},
#  {'country_name': 'Gibraltar',
#   'note': None,
#   'total_distance': '1.2 km',
#   'border_countries': None},
#  {'country_name': 'Greece',
#   'note': None,
#   'total_distance': '1,110 km',
#   'border_countries': None},
#  {'country_name': 'Greenland',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Grenada',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Guam',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Guatemala',
#   'note': None,
#   'total_distance': '1,667 km',
#   'border_countries': None},
#  {'country_name': 'Guernsey',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Guinea',
#   'note': None,
#   'total_distance': '4,046 km',
#   'border_countries': {'Cote': "d'Ivoire 816 km",
#    'Guinea-Bissau': '421 km',
#    'Liberia': '590 km',
#    'Mali': '1062 km',
#    'Senegal': '363 km',
#    'Sierra': 'Leone 794 km'}},
#  {'country_name': 'Guinea-Bissau',
#   'note': None,
#   'total_distance': '762 km',
#   'border_countries': None},
#  {'country_name': 'Guyana',
#   'note': None,
#   'total_distance': '2,933 km',
#   'border_countries': None},
#  {'country_name': 'Haiti',
#   'note': None,
#   'total_distance': '376 km',
#   'border_countries': None},
#  {'country_name': 'Heard Island and McDonald Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Holy See (Vatican City)',
#   'note': None,
#   'total_distance': '3.4 km',
#   'border_countries': None},
#  {'country_name': 'Honduras',
#   'note': None,
#   'total_distance': '1,575 km',
#   'border_countries': None},
#  {'country_name': 'Hong Kong',
#   'note': None,
#   'total_distance': '33 km',
#   'border_countries': None},
#  {'country_name': 'Hungary',
#   'note': None,
#   'total_distance': '2,106 km',
#   'border_countries': None},
#  {'country_name': 'Iceland',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'India',
#   'note': None,
#   'total_distance': '13,888 km',
#   'border_countries': {'Bangladesh': '4,142 km',
#    'Bhutan': '659 km',
#    'Burma': '1,468 km',
#    'China': '2,659 km',
#    'Nepal': '1,770 km',
#    'Pakistan': '3,190 km'}},
#  {'country_name': 'Indonesia',
#   'note': None,
#   'total_distance': '2,958 km',
#   'border_countries': None},
#  {'country_name': 'Iran',
#   'note': None,
#   'total_distance': '5,894 km',
#   'border_countries': None},
#  {'country_name': 'Iraq',
#   'note': None,
#   'total_distance': '3,809 km',
#   'border_countries': {'Iran': '1,599 km',
#    'Jordan': '179 km',
#    'Kuwait': '254 km',
#    'Saudi': 'Arabia 811 km',
#    'Syria': '599 km',
#    'Turkey': '367 km'}},
#  {'country_name': 'Ireland',
#   'note': None,
#   'total_distance': '490 km',
#   'border_countries': None},
#  {'country_name': 'Isle of Man',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Israel',
#   'note': None,
#   'total_distance': '1,068 km',
#   'border_countries': {'Egypt': '208 km',
#    'Gaza': 'Strip 59 km',
#    'Jordan': '327 km (20 km are within the Dead Sea)',
#    'Lebanon': '81 km',
#    'Syria': '83 km',
#    'West': 'Bank 330 km'}},
#  {'country_name': 'Italy',
#   'note': None,
#   'total_distance': '1,836.4 km',
#   'border_countries': {'Austria': '404 km',
#    'France': '476 km',
#    'Holy': 'See (Vatican City) 3.4 km',
#    'San': 'Marino 37 km',
#    'Slovenia': '218 km',
#    'Switzerland': '698 km'}},
#  {'country_name': 'Jamaica',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Jan Mayen',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Japan',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Jersey',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Jordan',
#   'note': None,
#   'total_distance': '1,744 km',
#   'border_countries': None},
#  {'country_name': 'Kazakhstan',
#   'note': None,
#   'total_distance': '13,364 km',
#   'border_countries': None},
#  {'country_name': 'Kenya',
#   'note': None,
#   'total_distance': '3,457 km',
#   'border_countries': None},
#  {'country_name': 'Kiribati',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Korea, North',
#   'note': None,
#   'total_distance': '1,607 km',
#   'border_countries': None},
#  {'country_name': 'Korea, South',
#   'note': None,
#   'total_distance': '237 km',
#   'border_countries': None},
#  {'country_name': 'Kosovo',
#   'note': None,
#   'total_distance': '714 km',
#   'border_countries': None},
#  {'country_name': 'Kuwait',
#   'note': None,
#   'total_distance': '475 km',
#   'border_countries': None},
#  {'country_name': 'Kyrgyzstan',
#   'note': None,
#   'total_distance': '4,573 km',
#   'border_countries': None},
#  {'country_name': 'Laos',
#   'note': None,
#   'total_distance': '5,274 km',
#   'border_countries': None},
#  {'country_name': 'Latvia',
#   'note': None,
#   'total_distance': '1,370 km',
#   'border_countries': None},
#  {'country_name': 'Lebanon',
#   'note': None,
#   'total_distance': '484 km',
#   'border_countries': None},
#  {'country_name': 'Lesotho',
#   'note': None,
#   'total_distance': '1,106 km',
#   'border_countries': None},
#  {'country_name': 'Liberia',
#   'note': None,
#   'total_distance': '1,667 km',
#   'border_countries': None},
#  {'country_name': 'Libya',
#   'note': None,
#   'total_distance': '4,339 km',
#   'border_countries': {'Algeria': '989 km',
#    'Chad': '1,050 km',
#    'Egypt': '1,115 km',
#    'Niger': '342 km',
#    'Sudan': '382 km',
#    'Tunisia': '461 km'}},
#  {'country_name': 'Liechtenstein',
#   'note': None,
#   'total_distance': '75 km',
#   'border_countries': None},
#  {'country_name': 'Lithuania',
#   'note': None,
#   'total_distance': '1,545 km',
#   'border_countries': None},
#  {'country_name': 'Luxembourg',
#   'note': None,
#   'total_distance': '327 km',
#   'border_countries': None},
#  {'country_name': 'Macau',
#   'note': None,
#   'total_distance': '3 km',
#   'border_countries': None},
#  {'country_name': 'Madagascar',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Malawi',
#   'note': None,
#   'total_distance': '2,857 km',
#   'border_countries': None},
#  {'country_name': 'Malaysia',
#   'note': None,
#   'total_distance': '2,742 km',
#   'border_countries': None},
#  {'country_name': 'Maldives',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Mali',
#   'note': None,
#   'total_distance': '7,908 km',
#   'border_countries': {'Algeria': '1,359 km',
#    'Burkina': 'Faso 1,325 km',
#    'Cote': "d'Ivoire 599 km",
#    'Guinea': '1,062 km',
#    'Mauritania': '2,236 km',
#    'Niger': '838 km, Senegal 489 km'}},
#  {'country_name': 'Malta',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Marshall Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Mauritania',
#   'note': None,
#   'total_distance': '5,002 km',
#   'border_countries': None},
#  {'country_name': 'Mauritius',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Mexico',
#   'note': None,
#   'total_distance': '4,389 km',
#   'border_countries': None},
#  {'country_name': 'Micronesia, Federated States of',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Moldova',
#   'note': None,
#   'total_distance': '1,885 km',
#   'border_countries': None},
#  {'country_name': 'Monaco',
#   'note': None,
#   'total_distance': '6 km',
#   'border_countries': None},
#  {'country_name': 'Mongolia',
#   'note': None,
#   'total_distance': '8,082 km',
#   'border_countries': None},
#  {'country_name': 'Montenegro',
#   'note': None,
#   'total_distance': '680 km',
#   'border_countries': None},
#  {'country_name': 'Montserrat',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Morocco',
#   'note': 'an additional 75-meter border segment exists between Morocco and the Spanish exclave of Penon de Velez de la Gomera',
#   'total_distance': '3,523.5 km',
#   'border_countries': None},
#  {'country_name': 'Mozambique',
#   'note': None,
#   'total_distance': '4,783 km',
#   'border_countries': {'Malawi': '1498 km',
#    'South': 'Africa 496 km',
#    'Eswatini': '108 km',
#    'Tanzania': '840 km',
#    'Zambia': '439 km',
#    'Zimbabwe': '1,402 km'}},
#  {'country_name': 'Namibia',
#   'note': None,
#   'total_distance': '4,220 km',
#   'border_countries': None},
#  {'country_name': 'Nauru',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Navassa Island',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Nepal',
#   'note': None,
#   'total_distance': '3,159 km',
#   'border_countries': None},
#  {'country_name': 'Netherlands',
#   'note': None,
#   'total_distance': '1,053 km',
#   'border_countries': None},
#  {'country_name': 'New Caledonia',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'New Zealand',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Nicaragua',
#   'note': None,
#   'total_distance': '1,253 km',
#   'border_countries': None},
#  {'country_name': 'Niger',
#   'note': None,
#   'total_distance': '5,834 km',
#   'border_countries': None},
#  {'country_name': 'Nigeria',
#   'note': None,
#   'total_distance': '4,477 km',
#   'border_countries': None},
#  {'country_name': 'Niue',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Norfolk Island',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'North Macedonia',
#   'note': None,
#   'total_distance': '838 km',
#   'border_countries': None},
#  {'country_name': 'Northern Mariana Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Norway',
#   'note': None,
#   'total_distance': '2,566 km',
#   'border_countries': None},
#  {'country_name': 'Oman',
#   'note': None,
#   'total_distance': '1,561 km',
#   'border_countries': None},
#  {'country_name': 'Pakistan',
#   'note': None,
#   'total_distance': '7,257 km',
#   'border_countries': None},
#  {'country_name': 'Palau',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Panama',
#   'note': None,
#   'total_distance': '687 km',
#   'border_countries': None},
#  {'country_name': 'Papua New Guinea',
#   'note': None,
#   'total_distance': '824 km',
#   'border_countries': None},
#  {'country_name': 'Paracel Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Paraguay',
#   'note': None,
#   'total_distance': '4,655 km',
#   'border_countries': None},
#  {'country_name': 'Peru',
#   'note': None,
#   'total_distance': '7,062 km',
#   'border_countries': None},
#  {'country_name': 'Philippines',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Pitcairn Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Poland',
#   'note': None,
#   'total_distance': '2,865 km',
#   'border_countries': {'Belarus': '375 km',
#    'Czechia': '699 km',
#    'Germany': '467 km',
#    'Lithuania': '100 km, Russia (Kaliningrad Oblast) 209 km',
#    'Slovakia': '517 km',
#    'Ukraine': '498 km'}},
#  {'country_name': 'Portugal',
#   'note': None,
#   'total_distance': '1,224 km',
#   'border_countries': None},
#  {'country_name': 'Puerto Rico',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Qatar',
#   'note': None,
#   'total_distance': '87 km',
#   'border_countries': None},
#  {'country_name': 'Romania',
#   'note': None,
#   'total_distance': '2,844 km',
#   'border_countries': None},
#  {'country_name': 'Russia',
#   'note': None,
#   'total_distance': '22,407 km',
#   'border_countries': None},
#  {'country_name': 'Rwanda',
#   'note': None,
#   'total_distance': '930 km',
#   'border_countries': None},
#  {'country_name': 'Saint Barthelemy',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Saint Helena, Ascension, and Tristan da Cunha',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Saint Kitts and Nevis',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Saint Lucia',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Saint Martin',
#   'note': None,
#   'total_distance': '16 km',
#   'border_countries': None},
#  {'country_name': 'Saint Pierre and Miquelon',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Saint Vincent and the Grenadines',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Samoa',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'San Marino',
#   'note': None,
#   'total_distance': '37 km',
#   'border_countries': None},
#  {'country_name': 'Sao Tome and Principe',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Saudi Arabia',
#   'note': None,
#   'total_distance': '4,272 km',
#   'border_countries': None},
#  {'country_name': 'Senegal',
#   'note': None,
#   'total_distance': '2,684 km',
#   'border_countries': None},
#  {'country_name': 'Serbia',
#   'note': None,
#   'total_distance': '2,322 km',
#   'border_countries': None},
#  {'country_name': 'Seychelles',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Sierra Leone',
#   'note': None,
#   'total_distance': '1,093 km',
#   'border_countries': None},
#  {'country_name': 'Singapore',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Sint Maarten',
#   'note': None,
#   'total_distance': '16 km',
#   'border_countries': None},
#  {'country_name': 'Slovakia',
#   'note': None,
#   'total_distance': '1,587 km',
#   'border_countries': None},
#  {'country_name': 'Slovenia',
#   'note': None,
#   'total_distance': '1,211 km',
#   'border_countries': None},
#  {'country_name': 'Solomon Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Somalia',
#   'note': None,
#   'total_distance': '2,385 km',
#   'border_countries': None},
#  {'country_name': 'South Africa',
#   'note': None,
#   'total_distance': '5,244 km',
#   'border_countries': {'Botswana': '1,969 km',
#    'Lesotho': '1,106 km',
#    'Mozambique': '496 km',
#    'Namibia': '1,005 km',
#    'Eswatini': '438 km',
#    'Zimbabwe': '230 km'}},
#  {'country_name': 'South Georgia and South Sandwich Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'South Sudan',
#   'note': 'South Sudan-Sudan boundary represents 1 January 1956 alignment; final alignment pending negotiations and demarcation; final sovereignty status of Abyei Area pending negotiations between South Sudan and Sudan',
#   'total_distance': '6,018 km',
#   'border_countries': {'Central': 'African Republic 1,055 km',
#    'Democratic': 'Republic of the Congo 714 km',
#    'Ethiopia': '1,299 km',
#    'Kenya': '317 km',
#    'Sudan': '2,158 km',
#    'Uganda': '475 km'}},
#  {'country_name': 'Spain',
#   'note': 'an additional 75-meter border segment exists between Morocco and the Spanish exclave of Penon de Velez de la Gomera',
#   'total_distance': '1,952.7 km',
#   'border_countries': None},
#  {'country_name': 'Spratly Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Sri Lanka',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Sudan',
#   'note': 'Sudan-South Sudan boundary represents 1 January 1956 alignment; final alignment pending negotiations and demarcation; final sovereignty status of Abyei region pending negotiations between Sudan and South Sudan',
#   'total_distance': '6,819 km',
#   'border_countries': None},
#  {'country_name': 'Suriname',
#   'note': None,
#   'total_distance': '1,907 km',
#   'border_countries': None},
#  {'country_name': 'Svalbard',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Sweden',
#   'note': None,
#   'total_distance': '2,211 km',
#   'border_countries': None},
#  {'country_name': 'Switzerland',
#   'note': None,
#   'total_distance': '1,770 km',
#   'border_countries': None},
#  {'country_name': 'Syria',
#   'note': None,
#   'total_distance': '2,363 km',
#   'border_countries': None},
#  {'country_name': 'Taiwan',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Tajikistan',
#   'note': None,
#   'total_distance': '4,130 km',
#   'border_countries': None},
#  {'country_name': 'Tanzania',
#   'note': None,
#   'total_distance': '4,161 km',
#   'border_countries': None},
#  {'country_name': 'Thailand',
#   'note': None,
#   'total_distance': '5,673 km',
#   'border_countries': None},
#  {'country_name': 'Timor-Leste',
#   'note': None,
#   'total_distance': '253 km',
#   'border_countries': None},
#  {'country_name': 'Togo',
#   'note': None,
#   'total_distance': '1,880 km',
#   'border_countries': None},
#  {'country_name': 'Tokelau',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Tonga',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Trinidad and Tobago',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Tunisia',
#   'note': None,
#   'total_distance': '1,495 km',
#   'border_countries': None},
#  {'country_name': 'Turkey (Turkiye)',
#   'note': None,
#   'total_distance': '2,816 km',
#   'border_countries': None},
#  {'country_name': 'Turkmenistan',
#   'note': None,
#   'total_distance': '4,158 km',
#   'border_countries': None},
#  {'country_name': 'Turks and Caicos Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Tuvalu',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Uganda',
#   'note': None,
#   'total_distance': '2,729 km',
#   'border_countries': None},
#  {'country_name': 'Ukraine',
#   'note': None,
#   'total_distance': '5,581 km',
#   'border_countries': {'Belarus': '1,111 km',
#    'Hungary': '128 km',
#    'Moldova': '1,202 km',
#    'Poland': '498 km',
#    'Romania': '601 km',
#    'Russia': '1,944 km, Slovakia 97 km'}},
#  {'country_name': 'United Arab Emirates',
#   'note': None,
#   'total_distance': '1,066 km',
#   'border_countries': None},
#  {'country_name': 'United Kingdom',
#   'note': None,
#   'total_distance': '499 km',
#   'border_countries': None},
#  {'country_name': 'United States',
#   'note': 'US Naval Base at Guantanamo Bay, Cuba is leased by the US and is part of Cuba; the base boundary is 28.5 km',
#   'total_distance': '12,002 km',
#   'border_countries': None},
#  {'country_name': 'United States Pacific Island Wildlife Refuges',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Uruguay',
#   'note': None,
#   'total_distance': '1,591 km',
#   'border_countries': None},
#  {'country_name': 'Uzbekistan',
#   'note': None,
#   'total_distance': '6,893 km',
#   'border_countries': None},
#  {'country_name': 'Vanuatu',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Venezuela',
#   'note': None,
#   'total_distance': '5,267 km',
#   'border_countries': None},
#  {'country_name': 'Vietnam',
#   'note': None,
#   'total_distance': '4,616 km',
#   'border_countries': None},
#  {'country_name': 'Virgin Islands',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Wake Island',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'Wallis and Futuna',
#   'note': None,
#   'total_distance': '0 km',
#   'border_countries': None},
#  {'country_name': 'West Bank',
#   'note': None,
#   'total_distance': '478 km',
#   'border_countries': None},
#  {'country_name': 'World',
#   'note': None,
#   'total_distance': None,
#   'border_countries': None},
#  {'country_name': 'Yemen',
#   'note': None,
#   'total_distance': '1,601 km',
#   'border_countries': None},
#  {'country_name': 'Zambia',
#   'note': None,
#   'total_distance': '6,043.15 km',
#   'border_countries': None},
#  {'country_name': 'Zimbabwe',
#   'note': None,
#   'total_distance': '3,229 km',
#   'border_countries': None}]

# %%
def print_country_info(country_info):
    if 'country_name' in country_info:
        print("Country Name:", country_info['country_name'])
    else:
        print("Country Name: Not Available")

    if 'total_distance' in country_info:
        print("Total Distance:", country_info['total_distance'])
    else:
        print("Total Distance: Not Available")

    if 'border_countries' in country_info:
        print("Border Countries:")
        border_countries = country_info['border_countries']
        if border_countries is None:
            print('NO border countries')
        else:
            for country, distance in border_countries.items():
                print(f"- {country}: {distance}")
    else:
        print("Border Countries: Not Available")
    if 'note' in country_info:
        print("Note:", country_info['note'])
    else:
        print("Note: Not Available")

# %%
for element in elements:
    print_country_info(element)
    print("--------------------")
# Out:
# Country Name: Afghanistan
# Total Distance: 5,987 km
# Border Countries:
# - China: 91 km
# - Iran: 921 km
# - Pakistan: 2,670 km
# - Tajikistan: 1,357 km
# - Turkmenistan: 804 km
# - Uzbekistan: 144 km
# Note: None
# --------------------
# Country Name: Akrotiri
# Total Distance: 48 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Albania
# Total Distance: 691 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Algeria
# Total Distance: 6,734 km
# Border Countries:
# - Libya: 989 km
# - Mali: 1,359 km
# - Mauritania: 460 km
# - Morocco: 1,941 km
# - Niger: 951 km
# - Tunisia: 1,034 km
# Note: None
# --------------------
# Country Name: American Samoa
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Andorra
# Total Distance: 118 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Angola
# Total Distance: 5,369 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Anguilla
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Antarctica
# Total Distance: None
# Border Countries:
# NO border countries
# Note: see entry on Disputes - international
# --------------------
# Country Name: Antigua and Barbuda
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Argentina
# Total Distance: 11,968 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Armenia
# Total Distance: 1,570 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Aruba
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Ashmore and Cartier Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Australia
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Austria
# Total Distance: 2,524 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Azerbaijan
# Total Distance: 2,468 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bahamas, The
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bahrain
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bangladesh
# Total Distance: 4,413 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Barbados
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Belarus
# Total Distance: 3,599 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Belgium
# Total Distance: 1,297 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Belize
# Total Distance: 542 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Benin
# Total Distance: 2,123 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bermuda
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bhutan
# Total Distance: 1,136 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bolivia
# Total Distance: 7,252 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bosnia and Herzegovina
# Total Distance: 1,543 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Botswana
# Total Distance: 4,347.15 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bouvet Island
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Brazil
# Total Distance: 16,145 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: British Indian Ocean Territory
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: British Virgin Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Brunei
# Total Distance: 266 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Bulgaria
# Total Distance: 1,806 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Burkina Faso
# Total Distance: 3,611 km
# Border Countries:
# - Benin: 386 km
# - Cote: d'Ivoire 545 km
# - Ghana: 602 km
# - Mali: 1325 km
# - Niger: 622 km
# - Togo: 131 km
# Note: None
# --------------------
# Country Name: Burma
# Total Distance: 6,522 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Burundi
# Total Distance: 1,140 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cabo Verde
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cambodia
# Total Distance: 2,530 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cameroon
# Total Distance: 5,018 km
# Border Countries:
# - Central: African Republic 901 km
# - Chad: 1,116 km
# - Republic: of the Congo 494 km
# - Equatorial: Guinea 183 km
# - Gabon: 349 km
# - Nigeria: 1975 km
# Note: None
# --------------------
# Country Name: Canada
# Total Distance: 8,892 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cayman Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Central African Republic
# Total Distance: 5,920 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Chad
# Total Distance: 6,406 km
# Border Countries:
# - Cameroon: 1,116 km
# - Central: African Republic 1,556 km
# - Libya: 1,050 km
# - Niger: 1,196 km
# - Nigeria: 85 km
# - Sudan: 1,403 km
# Note: None
# --------------------
# Country Name: Chile
# Total Distance: 7,801 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: China
# Total Distance: 22,457 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Christmas Island
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Clipperton Island
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cocos (Keeling) Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Colombia
# Total Distance: 6,672 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Comoros
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Congo, Democratic Republic of the
# Total Distance: 11,027 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Congo, Republic of the
# Total Distance: 5,554 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cook Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Coral Sea Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Costa Rica
# Total Distance: 661 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cote d'Ivoire
# Total Distance: 3,458 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Croatia
# Total Distance: 2,237 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cuba
# Total Distance: 28.5 km
# Border Countries:
# NO border countries
# Note: Guantanamo Naval Base is leased by the US and remains part of Cuba
# --------------------
# Country Name: Curacao
# Total Distance: None
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Cyprus
# Total Distance: 156 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Czechia
# Total Distance: 2,046 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Denmark
# Total Distance: 141 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Dhekelia
# Total Distance: 108 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Djibouti
# Total Distance: 528 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Dominica
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Dominican Republic
# Total Distance: 376 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Ecuador
# Total Distance: 2,237 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Egypt
# Total Distance: 2,612 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: El Salvador
# Total Distance: 590 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Equatorial Guinea
# Total Distance: 528 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Eritrea
# Total Distance: 1,840 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Estonia
# Total Distance: 657 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Eswatini
# Total Distance: 546 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Ethiopia
# Total Distance: 5,925 km
# Border Countries:
# - Djibouti: 342 km
# - Eritrea: 1,033 km
# - Kenya: 867 km
# - Somalia: 1,640 km
# - South: Sudan 1,299 km
# - Sudan: 744 km
# Note: None
# --------------------
# Country Name: European Union
# Total Distance: 13,770 km
# Border Countries:
# NO border countries
# Note: data for European continent only
# --------------------
# Country Name: Falkland Islands (Islas Malvinas)
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Faroe Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Fiji
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Finland
# Total Distance: 2,563 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: France
# Total Distance: 3,956 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: French Polynesia
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: French Southern and Antarctic Lands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Gabon
# Total Distance: 3,261 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Gambia, The
# Total Distance: 749 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Gaza Strip
# Total Distance: 72 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Georgia
# Total Distance: 1,814 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Germany
# Total Distance: 3,694 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Ghana
# Total Distance: 2,420 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Gibraltar
# Total Distance: 1.2 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Greece
# Total Distance: 1,110 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Greenland
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Grenada
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Guam
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Guatemala
# Total Distance: 1,667 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Guernsey
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Guinea
# Total Distance: 4,046 km
# Border Countries:
# - Cote: d'Ivoire 816 km
# - Guinea-Bissau: 421 km
# - Liberia: 590 km
# - Mali: 1062 km
# - Senegal: 363 km
# - Sierra: Leone 794 km
# Note: None
# --------------------
# Country Name: Guinea-Bissau
# Total Distance: 762 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Guyana
# Total Distance: 2,933 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Haiti
# Total Distance: 376 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Heard Island and McDonald Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Holy See (Vatican City)
# Total Distance: 3.4 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Honduras
# Total Distance: 1,575 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Hong Kong
# Total Distance: 33 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Hungary
# Total Distance: 2,106 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Iceland
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: India
# Total Distance: 13,888 km
# Border Countries:
# - Bangladesh: 4,142 km
# - Bhutan: 659 km
# - Burma: 1,468 km
# - China: 2,659 km
# - Nepal: 1,770 km
# - Pakistan: 3,190 km
# Note: None
# --------------------
# Country Name: Indonesia
# Total Distance: 2,958 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Iran
# Total Distance: 5,894 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Iraq
# Total Distance: 3,809 km
# Border Countries:
# - Iran: 1,599 km
# - Jordan: 179 km
# - Kuwait: 254 km
# - Saudi: Arabia 811 km
# - Syria: 599 km
# - Turkey: 367 km
# Note: None
# --------------------
# Country Name: Ireland
# Total Distance: 490 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Isle of Man
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Israel
# Total Distance: 1,068 km
# Border Countries:
# - Egypt: 208 km
# - Gaza: Strip 59 km
# - Jordan: 327 km (20 km are within the Dead Sea)
# - Lebanon: 81 km
# - Syria: 83 km
# - West: Bank 330 km
# Note: None
# --------------------
# Country Name: Italy
# Total Distance: 1,836.4 km
# Border Countries:
# - Austria: 404 km
# - France: 476 km
# - Holy: See (Vatican City) 3.4 km
# - San: Marino 37 km
# - Slovenia: 218 km
# - Switzerland: 698 km
# Note: None
# --------------------
# Country Name: Jamaica
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Jan Mayen
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Japan
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Jersey
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Jordan
# Total Distance: 1,744 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Kazakhstan
# Total Distance: 13,364 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Kenya
# Total Distance: 3,457 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Kiribati
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Korea, North
# Total Distance: 1,607 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Korea, South
# Total Distance: 237 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Kosovo
# Total Distance: 714 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Kuwait
# Total Distance: 475 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Kyrgyzstan
# Total Distance: 4,573 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Laos
# Total Distance: 5,274 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Latvia
# Total Distance: 1,370 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Lebanon
# Total Distance: 484 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Lesotho
# Total Distance: 1,106 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Liberia
# Total Distance: 1,667 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Libya
# Total Distance: 4,339 km
# Border Countries:
# - Algeria: 989 km
# - Chad: 1,050 km
# - Egypt: 1,115 km
# - Niger: 342 km
# - Sudan: 382 km
# - Tunisia: 461 km
# Note: None
# --------------------
# Country Name: Liechtenstein
# Total Distance: 75 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Lithuania
# Total Distance: 1,545 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Luxembourg
# Total Distance: 327 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Macau
# Total Distance: 3 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Madagascar
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Malawi
# Total Distance: 2,857 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Malaysia
# Total Distance: 2,742 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Maldives
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Mali
# Total Distance: 7,908 km
# Border Countries:
# - Algeria: 1,359 km
# - Burkina: Faso 1,325 km
# - Cote: d'Ivoire 599 km
# - Guinea: 1,062 km
# - Mauritania: 2,236 km
# - Niger: 838 km, Senegal 489 km
# Note: None
# --------------------
# Country Name: Malta
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Marshall Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Mauritania
# Total Distance: 5,002 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Mauritius
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Mexico
# Total Distance: 4,389 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Micronesia, Federated States of
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Moldova
# Total Distance: 1,885 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Monaco
# Total Distance: 6 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Mongolia
# Total Distance: 8,082 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Montenegro
# Total Distance: 680 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Montserrat
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Morocco
# Total Distance: 3,523.5 km
# Border Countries:
# NO border countries
# Note: an additional 75-meter border segment exists between Morocco and the Spanish exclave of Penon de Velez de la Gomera
# --------------------
# Country Name: Mozambique
# Total Distance: 4,783 km
# Border Countries:
# - Malawi: 1498 km
# - South: Africa 496 km
# - Eswatini: 108 km
# - Tanzania: 840 km
# - Zambia: 439 km
# - Zimbabwe: 1,402 km
# Note: None
# --------------------
# Country Name: Namibia
# Total Distance: 4,220 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Nauru
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Navassa Island
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Nepal
# Total Distance: 3,159 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Netherlands
# Total Distance: 1,053 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: New Caledonia
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: New Zealand
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Nicaragua
# Total Distance: 1,253 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Niger
# Total Distance: 5,834 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Nigeria
# Total Distance: 4,477 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Niue
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Norfolk Island
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: North Macedonia
# Total Distance: 838 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Northern Mariana Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Norway
# Total Distance: 2,566 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Oman
# Total Distance: 1,561 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Pakistan
# Total Distance: 7,257 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Palau
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Panama
# Total Distance: 687 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Papua New Guinea
# Total Distance: 824 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Paracel Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Paraguay
# Total Distance: 4,655 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Peru
# Total Distance: 7,062 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Philippines
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Pitcairn Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Poland
# Total Distance: 2,865 km
# Border Countries:
# - Belarus: 375 km
# - Czechia: 699 km
# - Germany: 467 km
# - Lithuania: 100 km, Russia (Kaliningrad Oblast) 209 km
# - Slovakia: 517 km
# - Ukraine: 498 km
# Note: None
# --------------------
# Country Name: Portugal
# Total Distance: 1,224 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Puerto Rico
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Qatar
# Total Distance: 87 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Romania
# Total Distance: 2,844 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Russia
# Total Distance: 22,407 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Rwanda
# Total Distance: 930 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Saint Barthelemy
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Saint Helena, Ascension, and Tristan da Cunha
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Saint Kitts and Nevis
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Saint Lucia
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Saint Martin
# Total Distance: 16 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Saint Pierre and Miquelon
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Saint Vincent and the Grenadines
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Samoa
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: San Marino
# Total Distance: 37 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Sao Tome and Principe
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Saudi Arabia
# Total Distance: 4,272 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Senegal
# Total Distance: 2,684 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Serbia
# Total Distance: 2,322 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Seychelles
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Sierra Leone
# Total Distance: 1,093 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Singapore
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Sint Maarten
# Total Distance: 16 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Slovakia
# Total Distance: 1,587 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Slovenia
# Total Distance: 1,211 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Solomon Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Somalia
# Total Distance: 2,385 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: South Africa
# Total Distance: 5,244 km
# Border Countries:
# - Botswana: 1,969 km
# - Lesotho: 1,106 km
# - Mozambique: 496 km
# - Namibia: 1,005 km
# - Eswatini: 438 km
# - Zimbabwe: 230 km
# Note: None
# --------------------
# Country Name: South Georgia and South Sandwich Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: South Sudan
# Total Distance: 6,018 km
# Border Countries:
# - Central: African Republic 1,055 km
# - Democratic: Republic of the Congo 714 km
# - Ethiopia: 1,299 km
# - Kenya: 317 km
# - Sudan: 2,158 km
# - Uganda: 475 km
# Note: South Sudan-Sudan boundary represents 1 January 1956 alignment; final alignment pending negotiations and demarcation; final sovereignty status of Abyei Area pending negotiations between South Sudan and Sudan
# --------------------
# Country Name: Spain
# Total Distance: 1,952.7 km
# Border Countries:
# NO border countries
# Note: an additional 75-meter border segment exists between Morocco and the Spanish exclave of Penon de Velez de la Gomera
# --------------------
# Country Name: Spratly Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Sri Lanka
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Sudan
# Total Distance: 6,819 km
# Border Countries:
# NO border countries
# Note: Sudan-South Sudan boundary represents 1 January 1956 alignment; final alignment pending negotiations and demarcation; final sovereignty status of Abyei region pending negotiations between Sudan and South Sudan
# --------------------
# Country Name: Suriname
# Total Distance: 1,907 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Svalbard
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Sweden
# Total Distance: 2,211 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Switzerland
# Total Distance: 1,770 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Syria
# Total Distance: 2,363 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Taiwan
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Tajikistan
# Total Distance: 4,130 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Tanzania
# Total Distance: 4,161 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Thailand
# Total Distance: 5,673 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Timor-Leste
# Total Distance: 253 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Togo
# Total Distance: 1,880 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Tokelau
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Tonga
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Trinidad and Tobago
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Tunisia
# Total Distance: 1,495 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Turkey (Turkiye)
# Total Distance: 2,816 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Turkmenistan
# Total Distance: 4,158 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Turks and Caicos Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Tuvalu
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Uganda
# Total Distance: 2,729 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Ukraine
# Total Distance: 5,581 km
# Border Countries:
# - Belarus: 1,111 km
# - Hungary: 128 km
# - Moldova: 1,202 km
# - Poland: 498 km
# - Romania: 601 km
# - Russia: 1,944 km, Slovakia 97 km
# Note: None
# --------------------
# Country Name: United Arab Emirates
# Total Distance: 1,066 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: United Kingdom
# Total Distance: 499 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: United States
# Total Distance: 12,002 km
# Border Countries:
# NO border countries
# Note: US Naval Base at Guantanamo Bay, Cuba is leased by the US and is part of Cuba; the base boundary is 28.5 km
# --------------------
# Country Name: United States Pacific Island Wildlife Refuges
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Uruguay
# Total Distance: 1,591 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Uzbekistan
# Total Distance: 6,893 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Vanuatu
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Venezuela
# Total Distance: 5,267 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Vietnam
# Total Distance: 4,616 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Virgin Islands
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Wake Island
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Wallis and Futuna
# Total Distance: 0 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: West Bank
# Total Distance: 478 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: World
# Total Distance: None
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Yemen
# Total Distance: 1,601 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Zambia
# Total Distance: 6,043.15 km
# Border Countries:
# NO border countries
# Note: None
# --------------------
# Country Name: Zimbabwe
# Total Distance: 3,229 km
# Border Countries:
# NO border countries
# Note: None
# --------------------

# %%
len(elements)
# Out:
# 255

# %%
import csv
def save_data_2_csv(country_info_list, filename):
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Country Name', 'Total Distance', 'Border Countries']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        
        for country_info in country_info_list:
            writer.writerow({
                'Country Name': country_info.get('country_name', 'Not Available'),
                'Border Countries': ', '.join(country_info.get('border_countries', {}).keys()) if country_info.get('border_countries') else 'No border countries',
                'Total Distance': country_info.get('total_distance', 'Not Available')
            })

# %%
save_data_2_csv(elements,'country_info.csv')

# %%
import xml.etree.ElementTree as ET

def save_country_info_to_xml(country_info_list, filename):
    root = ET.Element("countries")

    for country_info in country_info_list:
        country_element = ET.SubElement(root, "country")
        
        country_name_element = ET.SubElement(country_element, "country_name")
        country_name_element.text = country_info.get('country_name', 'Not Available')

        total_distance_element = ET.SubElement(country_element, "total_distance")
        total_distance_element.text = country_info.get('total_distance', 'Not Available')

        note_element = ET.SubElement(country_element, "notes")
        country_name_element.text = country_info.get('note', 'Not Available')        
    tree = ET.ElementTree(root)
    tree.write(filename)

# %%
save_country_info_to_xml(elements, 'country_info.xml')
